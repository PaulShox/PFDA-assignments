# %% [markdown]
# # ***Weather.ipynb***
# ### A project to plot weather data from Knock Airport
# ### Author: Paul O'Shaughnessy

# %% [markdown]
# ## **1. Import Libraries and Data**

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('hly4935.csv', skiprows=23)
data.head(5)
# Out:
# C:\Users\posea\AppData\Local\Temp\ipykernel_14616\3453887239.py:1: DtypeWarning: Columns (2,10,12,14,15,16,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('hly4935.csv', skiprows=23)
#                date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0  10/04/1996 14:00    0    0      0  11.5      0   8.1    3.9    0.0     0
# 1  31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 2  31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 3  31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0     0
# 4  31/07/1996 11:00    0    0      0  14.5      0  10.8    7.0    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 0  ...     0     0     0      0  25  81  0.0  35000   32     5
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# ...

# %%
data.drop(0, inplace=True)
data.head(3)
# Out:
#                date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 1  31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 2  31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 3  31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# 3  ...     0     0     0      0  25  82  0.0  28000   35     6
#
# [3 rows x 21 columns]

# %% [markdown]
# ## **2. Check Data Types and convert where necessary**

# %%
data.dtypes
# Out:
# date      object
# ind        int64
# rain      object
# ind.1      int64
# temp     float64
# ind.2      int64
# wetb     float64
# dewpt    float64
# vappr    float64
# rhum       int64
# msl       object
# ind.3      int64
# wdsp      object
# ind.4      int64
# wddir     object
# ww        object
# w         object
# sun      float64
# vis       object
# clht      object
# clamt     object
# dtype: object

# %%
# Convert date column data type from object to datetime
data['date'] = pd.to_datetime(data['date'])
# Out:
# C:\Users\posea\AppData\Local\Temp\ipykernel_14616\70253330.py:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['date'] = pd.to_datetime(data['date'])

# %%
data.dtypes
# Out:
# date     datetime64[ns]
# ind               int64
# rain             object
# ind.1             int64
# temp            float64
# ind.2             int64
# wetb            float64
# dewpt           float64
# vappr           float64
# rhum              int64
# msl              object
# ind.3             int64
# wdsp             object
# ind.4             int64
# wddir            object
# ww               object
# w                object
# sun             float64
# vis              object
# clht             object
# clamt            object
# dtype: object

# %% [markdown]
# ## **3. Make the Date Column the Index Column**

# %%
data.set_index('date', inplace=True)
data.head(3)
# Out:
#                      ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# date
# 1996-07-31 08:00:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 1996-07-31 09:00:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 1996-07-31 10:00:00    0    0      0  12.9      0  11.3    9.8    0.0     0
#
#                         msl  ind.3 wdsp  ind.4 wddir  ww   w  sun    vis clht  \
# date
# 1996-07-31 08:00:00  1011.4      0    0      0     0  25  82  0.0  40000   45
# 1996-07-31 09:00:00  1011.4      0    0      0     0  80  81  0.0   8000   32
# 1996-07-31 10:00:00  1011.2      0    0      0     0  25  82  0.0  28000   35
#
#                     clamt
# date
# 1996-07-31 08:00:00     5
# 1996-07-31 09:00:00     7
# 1996-07-31 10:00:00     6

# %% [markdown]
# ## **4. Plot Temperature**

# %% [markdown]
# ### *Using Entire Dataset*

# %%
# Plot Temperature
fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(data['temp']).set_title('Temperature 1996-2024', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Temperature 1996-2024')

# %% [markdown]
# ### *Using data from 3 days*

# %%
datefrom = '2019/01/01 00:00'
dateto = '2019/01/03 23:00'
fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(data=data.loc[datefrom:dateto], x='date', y='temp').set_title('Temperature 1st - 3rd January 2019', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Temperature 1st - 3rd January 2019')

# %% [markdown]
# ## **5. Plot Average Daily Temperature**

# %% [markdown]
# ### *Using Entire Datase*

# %%
# Plot Average Daily Temperature
avg_d = data['temp'].resample('1d').mean()

fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(avg_d).set_title('Average Daily Temperature', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Average Daily Temperature')

# %% [markdown]
# ### *Using Data from 1 Month*

# %%
avg_d = data['temp'].resample('1d').mean()
datefrom = '2019/01/01'
dateto = '2019/01/31'
daily_avg = avg_d.loc[datefrom:dateto]
fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(daily_avg).set_title('Average Daily Temperature January 2019', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Average Daily Temperature January 2019')

# %% [markdown]
# ## **6. Plot Average Monthly Temperature**

# %% [markdown]
# ### *Using Entire Dataset*

# %%
# Plot Average Monthly Temperature
avg_m = data['temp'].resample('1m').mean()

fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(avg_m).set_title('Average Monthly Temperature', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Average Monthly Temperature')

# %% [markdown]
# ### *Using data from 1 Year*

# %%
avg_m = data['temp'].resample('1m').mean()
date_from = '2019/01/01'
date_to = '2019/12/31'
monthly_avg = avg_m[date_from:date_to]
fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(monthly_avg).set_title('Average Monthly Temperature 2019', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Average Monthly Temperature 2019')

# %% [markdown]
# ## **7. Plot Windspeed**

# %% [markdown]
# *Check data type of windspeed column*

# %%
data['wdsp'].dtype
# Out:
# dtype('O')

# %% [markdown]
# *Data type 'O' means there are mixed data types in the column*
#
# *This means various codes are required to find Zero, NaN, Null, and Blank Values*

# %%
data['wdsp'].isnull().sum()
# Out:
# 0

# %%
data['wdsp'].isna().sum()
# Out:
# 0

# %%
data['wdsp'].value_counts().get('0')
# Out:
# 279

# %%
data['wdsp'].value_counts().get(0)
# Out:
# 128

# %%
# https://stackoverflow.com/questions/49677060/pandas-count-empty-strings-in-a-column
(data['wdsp'].values == ' ').sum()
# Out:
# 50

# %% [markdown]
# *Per the above, the windspeed column has 407 zero values, and 50 blank values*
#
# *The blank string cells pose a problem as they won't allow the column to be converted to the int data type*
#
# *Therefore they will be replaced with the number 0*

# %%
data['wdsp'] = data['wdsp'].replace(' ', 0)

# %%
(data['wdsp'].values == ' ').sum()
# Out:
# 0

# %% [markdown]
# *It can now be seen that the number of int 0 values has gone from 128 to 178*

# %%
data['wdsp'].value_counts().get(0)
# Out:
# 178

# %% [markdown]
# *Convert windspeed column data type to int*

# %%
# https://www.geeksforgeeks.org/convert-a-dataframe-column-to-integer-in-pandas/
data['wdsp'] = data['wdsp'].map(int)

# %%
data['wdsp'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# *Replace all zero values with average value*

# %%
# https://stackoverflow.com/questions/69921516/replace-value-with-the-average-of-its-column-with-pandas
avg = data['wdsp'].mean()
data['wdsp'] = data['wdsp'].apply(lambda v: avg if v==0 else v)

# %% [markdown]
# *Check zero values have been replaced*

# %%
data['wdsp'].value_counts().get(0)

# %%
data['wdsp'].head(10)
# Out:
# date
# 1996-07-31 08:00:00    9.457684
# 1996-07-31 09:00:00    9.457684
# 1996-07-31 10:00:00    9.457684
# 1996-07-31 11:00:00    9.457684
# 1996-07-31 12:00:00    9.457684
# 1996-07-31 13:00:00    9.457684
# 1996-07-31 14:00:00    9.457684
# 1996-07-31 15:00:00    9.457684
# 1996-07-31 16:00:00    9.457684
# 1996-07-31 17:00:00    9.457684
# Name: wdsp, dtype: float64

# %% [markdown]
# *Plot the windspeed - using data from 1 year only*

# %%
date_From = '2019/01/01'
date_To = '2019/12/31'

fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(data=data.loc[date_From:date_To], x='date', y='wdsp').set_title('Windspeed 2019', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Windspeed 2019')

# %% [markdown]
# ## **8. Plot One Day Rolling Windspeed Average**

# %%
avg_roll = data['wdsp'].rolling('1d').mean()
d_from = '2019/01/01'
d_to = '2019/12/31'
roll_avg = avg_roll[d_from:d_to]
fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(roll_avg).set_title('1 Day Rolling Windspeed Average - 2019', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, '1 Day Rolling Windspeed Average - 2019')

# %% [markdown]
# ## **9. Plot Maximum Wind Speed Each Day**

# %% [markdown]
# *Using data from 1 Year*

# %%
wind_max = data['wdsp'].resample('1d').max()
dt_frm = '2019/01/01'
dt_to = '2019/12/31'
max_wind = wind_max[dt_frm:dt_to]
fig = plt.subplots(figsize=(20, 5))
plt.style.use('ggplot')
sns.lineplot(max_wind).set_title('Daily Maximum Wind Speed - 2019', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Daily Maximum Wind Speed - 2019')

# %% [markdown]
# ### *10. Monthly mean of daily max windspeeds*
#
# Did not attempt

# %% [markdown]
# ______________

# %% [markdown]
# # **End**
