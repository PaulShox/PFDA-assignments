# %% [markdown]
# # ***Weather.ipynb***
# ### A project to plot weather data
# ### Author: Paul O'Shaughnessy

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('hly4935.csv', skiprows=23)
data.head(5)
# Out:
# C:\Users\posea\AppData\Local\Temp\ipykernel_22700\3453887239.py:1: DtypeWarning: Columns (2,10,12,14,15,16,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('hly4935.csv', skiprows=23)
#                date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0  10/04/1996 14:00    0    0      0  11.5      0   8.1    3.9    0.0     0
# 1  31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 2  31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 3  31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0     0
# 4  31/07/1996 11:00    0    0      0  14.5      0  10.8    7.0    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 0  ...     0     0     0      0  25  81  0.0  35000   32     5
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# ...

# %%
data.drop(0, inplace=True)
data.head(3)
# Out:
#                date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 1  31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 2  31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 3  31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# 3  ...     0     0     0      0  25  82  0.0  28000   35     6
#
# [3 rows x 21 columns]

# %%
data.dtypes
# Out:
# date      object
# ind        int64
# rain      object
# ind.1      int64
# temp     float64
# ind.2      int64
# wetb     float64
# dewpt    float64
# vappr    float64
# rhum       int64
# msl       object
# ind.3      int64
# wdsp      object
# ind.4      int64
# wddir     object
# ww        object
# w         object
# sun      float64
# vis       object
# clht      object
# clamt     object
# dtype: object

# %%
data['date'] = pd.to_datetime(data['date'])
# Out:
# C:\Users\posea\AppData\Local\Temp\ipykernel_22700\736794659.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['date'] = pd.to_datetime(data['date'])

# %%
data.dtypes
# Out:
# date     datetime64[ns]
# ind               int64
# rain             object
# ind.1             int64
# temp            float64
# ind.2             int64
# wetb            float64
# dewpt           float64
# vappr           float64
# rhum              int64
# msl              object
# ind.3             int64
# wdsp             object
# ind.4             int64
# wddir            object
# ww               object
# w                object
# sun             float64
# vis              object
# clht             object
# clamt            object
# dtype: object

# %%
data.set_index('date', inplace=True)
data.head(3)
# Out:
#                      ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# date
# 1996-07-31 08:00:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 1996-07-31 09:00:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 1996-07-31 10:00:00    0    0      0  12.9      0  11.3    9.8    0.0     0
#
#                         msl  ind.3 wdsp  ind.4 wddir  ww   w  sun    vis clht  \
# date
# 1996-07-31 08:00:00  1011.4      0    0      0     0  25  82  0.0  40000   45
# 1996-07-31 09:00:00  1011.4      0    0      0     0  80  81  0.0   8000   32
# 1996-07-31 10:00:00  1011.2      0    0      0     0  25  82  0.0  28000   35
#
#                     clamt
# date
# 1996-07-31 08:00:00     5
# 1996-07-31 09:00:00     7
# 1996-07-31 10:00:00     6

# %%
fig = plt.subplots(figsize=(20, 5))
sns.lineplot(data['temp']).set_title('Temperature', fontsize=20, fontweight='bold')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Temperature')

# %%
avg_d = data['temp'].resample('1d').mean()

fig = plt.subplots(figsize=(20, 5))
sns.lineplot(avg_d).set_title('Average Daily Temperature')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Average Daily Temperature')

# %%
avg_m = data['temp'].resample('1m').mean()

fig = plt.subplots(figsize=(20, 5))
sns.lineplot(avg_m).set_title('Average Monthly Temperature')
# Out:
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\posea\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Average Monthly Temperature')
